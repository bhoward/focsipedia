// %% [markdown]
// Examples from https://nbviewer.jupyter.org/github/almond-sh/almond-examples/blob/master/notebooks/visualization/evilplot.ipynb

// %%
interp.repositories() ++= Seq(
  coursierapi.MavenRepository.of("https://dl.bintray.com/cibotech/public")
)

// %%
import $ivy.`com.cibo::evilplot-repl:0.6.3`

def showPlot(plot: com.cibo.evilplot.geometry.Drawable) =
  Image.fromRenderedImage(plot.asBufferedImage, format=Image.PNG)
// Out:
// import $ivy.$
//
//
// defined function showPlot

// %%
import com.cibo.evilplot._
import com.cibo.evilplot.plot._
import com.cibo.evilplot.plot.aesthetics.DefaultTheme._
import com.cibo.evilplot.numeric.Point

val data = Seq.tabulate(100) { i =>
  Point(i.toDouble, scala.util.Random.nextDouble())
}

showPlot(ScatterPlot(data).render())
// Out:
// import com.cibo.evilplot._
//
// import com.cibo.evilplot.plot._
//
// import com.cibo.evilplot.plot.aesthetics.DefaultTheme._
//
// import com.cibo.evilplot.numeric.Point
//
//
// data: Seq[Point] = List(
//   Point(0.0, 0.6971852633960288),
//   Point(1.0, 0.08890785427155767),
//   Point(2.0, 0.2960921019970296),
//   Point(3.0, 0.1193921961237453),
//   Point(4.0, 0.9865889066443575),
//   Point(5.0, 0.7109941910922032),
//   Point(6.0, 0.9059898061048048),
//   Point(7.0, 0.4103377822644235),
//   Point(8.0, 0.5957277721587542),
//   Point(9.0, 0.991531634069304),
//   Point(10.0, 0.37133338477792033),
//   Point(11.0, 0.24454702014052254),
//   Point(12.0, 0.8161381736083517),
//   Point(13.0, 0.7085493441585672),
//   Point(14.0, 0.5454840758853187),
//   Point(15.0, 0.022097856141846006),
//   Point(16.0, 0.3931520746701648),
//   Point(17.0, 0.706983311227945),
//   Point(18.0, 0.21162970210530097),
//   Point(19.0, 0.5507588443762573),
//   Point(20.0, 0.6591601009467238),
//   Point(21.0, 0.9814938535705804),
//   Point(22.0, 0.22882903241247754),
//   Point(23.0, 0.1918238089606995),
//   Point(24.0, 0.620942307792975),
//   Point(25.0, 0.3509931802871914),
//   Point(26.0, 0.5854477493894608),
//   Point(27.0, 0.20442263669628047),
//   Point(28.0, 0.985106822726772),
//   Point(29.0, 0.1896352177875601),
//   Point(30.0, 0.9245916685920565),
//   Point(31.0, 0.9625326490747945),
//   Point(32.0, 0.9308702356255918),
//   Point(33.0, 0.8245277791350947),
//   Point(34.0, 0.8844632184206028),
//   Point(35.0, 0.9425482453496316),
//   Point(36.0, 0.42086037494062467),
//   Point(37.0, 0.7621847684027845),
// ...

// %%
import com.cibo.evilplot.plot._
import com.cibo.evilplot.plot.aesthetics.DefaultTheme._
import com.cibo.evilplot.numeric.Point

val data = Seq.tabulate(100) { i =>
  Point(i.toDouble, scala.util.Random.nextDouble())
}

val plot = ScatterPlot(data)
  .xAxis()
  .yAxis()
  .frame()
  .xLabel("x")
  .yLabel("y")
  .render()

showPlot(plot)
// Out:
// import com.cibo.evilplot.plot._
//
// import com.cibo.evilplot.plot.aesthetics.DefaultTheme._
//
// import com.cibo.evilplot.numeric.Point
//
//
// data: Seq[Point] = List(
//   Point(0.0, 0.7883680450555237),
//   Point(1.0, 0.5514449017557692),
//   Point(2.0, 0.6983639345418585),
//   Point(3.0, 0.7522322498353712),
//   Point(4.0, 0.5207996866736373),
//   Point(5.0, 0.19073065111421195),
//   Point(6.0, 0.31823930292637526),
//   Point(7.0, 0.026554971030793517),
//   Point(8.0, 0.9402381898409303),
//   Point(9.0, 0.7169044768607056),
//   Point(10.0, 0.8846399169739846),
//   Point(11.0, 0.6052743754135543),
//   Point(12.0, 0.617954177127608),
//   Point(13.0, 0.17948853665134956),
//   Point(14.0, 0.6059438140645061),
//   Point(15.0, 0.756333508668043),
//   Point(16.0, 0.7046472441716266),
//   Point(17.0, 0.9447574700811568),
//   Point(18.0, 0.39652299161259175),
//   Point(19.0, 0.07872930688913704),
//   Point(20.0, 0.63892403003736),
//   Point(21.0, 0.727436082547301),
//   Point(22.0, 0.7885088942320636),
//   Point(23.0, 0.2956681933114349),
//   Point(24.0, 0.3444209233455455),
//   Point(25.0, 0.8602558431301038),
//   Point(26.0, 0.737186527652087),
//   Point(27.0, 0.5666625493209089),
//   Point(28.0, 0.4044935088146068),
//   Point(29.0, 0.7788174924429168),
//   Point(30.0, 0.21762973122969254),
//   Point(31.0, 0.4586133319249198),
//   Point(32.0, 0.43484021944752815),
//   Point(33.0, 9.654260803272363E-4),
//   Point(34.0, 0.6947622507538697),
//   Point(35.0, 0.5958067347095846),
//   Point(36.0, 0.7621227524372974),
//   Point(37.0, 0.5878867457739472),
// ...
// plot: geometry.Drawable = Group(
//   Vector(
//     Translate(
//       StrokeStyle(
//         Group(
//           Vector(
//             Translate(Rotate(Line(549.0, 1.0), 90.0), -0.5000000000000168, 0.0),
//             Translate(Line(732.0126953125, 1.0), 0.0, 548.5)
//           )
//         ),
//         HSLA(0.0, 0.0, 12.0, 1.0)
//       ),
//       67.9873046875,
//       0.0
//     ),
//     Translate(
//       Resize(
//         Group(
//           Vector(
//             Translate(
//               Style(Translate(Disc(4.0), -4.0, -4.0), HSLA(0.0, 0.0, 12.0, 1.0)),
//               0.0,
//               116.1859432645175
//             ),
//             Translate(
//               Style(Translate(Disc(4.0), -4.0, -4.0), HSLA(0.0, 0.0, 12.0, 1.0)),
//               7.320126953125,
//               246.25674893608272
//             ),
//             Translate(
//               Style(Translate(Disc(4.0), -4.0, -4.0), HSLA(0.0, 0.0, 12.0, 1.0)),
//               14.64025390625,
//               165.59819993651968
//             ),
//             Translate(
//               Style(Translate(Disc(4.0), -4.0, -4.0), HSLA(0.0, 0.0, 12.0, 1.0))...
